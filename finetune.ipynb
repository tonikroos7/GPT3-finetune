# %%
# !pip install openai
# !pip install jsonlines
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: openai in /usr/local/lib/python3.9/dist-packages (0.27.2)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.9/dist-packages (from openai) (2.27.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.9/dist-packages (from openai) (3.8.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from openai) (4.65.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20->openai) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20->openai) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20->openai) (1.26.15)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->openai) (22.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/dist-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.9/dist-packages (from aiohttp->openai) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->openai) (1.8.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.9/dist-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from aiohttp->openai) (1.3.3)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: jsonlines in /usr/local/lib/python3.9/dist-packages (3.1.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.9/dist-packages (from jsonlines) (22.2.0)

# %%
import jsonlines

question,passage,answer=[],[],[]
with jsonlines.open('train.jsonl') as f:
    for line in f.iter():
        question.append(line['question']) # or whatever else you'd like to do
        passage.append(line['passage'])
        answer.append(line['answer'])

# %%
prompt="passage: \"The tower's tilt began during construction in the 12th century, caused by an inadequate foundation on ground too soft on one side to properly support the structure's weight. The tilt increased in the decades before the structure was completed in the 14th century. It gradually increased until the structure was stabilized (and the tilt partially corrected) by efforts in the late 20th and early 21st centuries.\"\nquestion: \"was the leaning tower of pisa built leaning\"\nanswer: false\n\npassage: \"In Australia, each state has its own constitution. Each state constitution preceded the Constitution of Australia as constitutions of the then separate British colonies, but all the states ceded powers to the Parliament of Australia as part of federation in 1901.\"\nquestion: \"does each australian state have its own constitution\"\nanswer: true\n\npassage: \"Justices are nominated by the president and then confirmed by the U.S. Senate. A nomination to the Court is considered to be official when the Senate receives a signed nomination letter from the president naming the nominee, which is then entered in the Senate's record. There have been 37 unsuccessful nominations to the Supreme Court of the United States. Of these, 11 nominees were rejected in Senate roll-call votes, 11 were withdrawn by the president, and 15 lapsed at the end of a session of Congress. Six of these unsuccessful nominees were subsequently nominated and confirmed to other seats on the Court. Additionally, although confirmed, seven nominees either declined office or (in one instance) died before assuming office.\"\nquestion: \"has any supreme court nominee not been confirmed\"\nanswer: true\n\npassage: \"This list contains the top 50 accounts with the most followers on the social photo-sharing platform Instagram. As of October 2018, the most followed user is Instagram's own account, with over 260 million followers. Cristiano Ronaldo is the most followed individual, with over 144 million followers. Twelve accounts have exceeded 100 million followers on the site.\"\nquestion: \"does anyone on instagram have 1 billion followers\"\nanswer: false\n\npassage: \"Creme eggs are available annually between 1 January and Easter Day. In the UK in the 1980s, Cadbury made Creme Eggs available year-round but sales dropped and they returned to seasonal availability.\"\nquestion: \"can you buy cadburys creme eggs all year round\"\nanswer: false\n\npassage: \"Station 19 is an American action-drama television series created by Stacy McKee for ABC. McKee, Shonda Rhimes, Betsy Beers, and Paris Barclay serve as executive producers on the series, which is the second spin-off to Grey's Anatomy. Set in Seattle, the series focuses on the lives of the men and women at Seattle Fire Station 19. The series is produced by Shondaland and ABC Studios, with McKee serving as showrunner.\"\nquestion: \"is station 19 a grey's anatomy spin off\"\nanswer: true"

# %%
import os
import openai
import numpy as np

openai.api_key = "OPENAI_API_KEY"

output = []
for i in range(30,60):
  pmt = "passage: " + passage[i] + "\nquestion: " + question[i] + "\nanswer: "
  response = openai.Completion.create(
  model="text-davinci-003",
  prompt= prompt + pmt,
  temperature=0.7,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)
  output.append(response)

# %%
output = []
for i in range(30,60):
  pmt = "passage: " + passage[i] + "\nquestion: " + question[i] + "\nanswer: "
  response = openai.Completion.create(
  model="text-davinci-003",
  prompt= prompt + pmt,
  temperature=0.7,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)
  output.append(response)

# %%
output
# Out:
# [<OpenAIObject text_completion id=cmpl-6zy4jJs9l5pDM1OtBA7BvubdZCann at 0x7fc670c0fa40> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": " true"
#      }
#    ],
#    "created": 1680226957,
#    "id": "cmpl-6zy4jJs9l5pDM1OtBA7BvubdZCann",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 1,
#      "prompt_tokens": 721,
#      "total_tokens": 722
#    }
#  },
#  <OpenAIObject text_completion id=cmpl-6zy4jFvVZTEklPciAzoDqZoZFtT0Q at 0x7fc67049b590> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": " False"
#      }
#    ],
#    "created": 1680226957,
#    "id": "cmpl-6zy4jFvVZTEklPciAzoDqZoZFtT0Q",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 1,
#      "prompt_tokens": 811,
#      "total_tokens": 812
#    }
#  },
#  <OpenAIObject text_completion id=cmpl-6zy4jzKzFGKI01T91WuKl2vHGaYgQ at 0x7fc6703588b0> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": " false"
#      }
#    ],
#    "created": 1680226957,
#    "id": "cmpl-6zy4jzKzFGKI01T91WuKl2vHGaYgQ",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 1,
#      "prompt_tokens": 713,
#      "total_tokens": 714
#    }
#  },
#  <OpenAIObject text_completion id=cmpl-6zy4kzCDD37JV72RHciO14tcubsmF at 0x7fc6704d7d60> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": " false"
#      }
#    ],
#    "created": 1680226958,
#    "id": "cmpl-6zy4kzCDD37JV72RHciO14tcubsmF",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 1,
#      "prompt_tokens": 701,
#      "total_tokens": 702
#    }
#  },
#  <OpenAIObject text_completion id=cmpl-6zy4kwwRZ4O3T6qN7QLQmvx3ztrnm at 0x7fc670c1e090> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": " false"
#      }
#    ],
#    "created": 1680226958,
#    "id": "cmpl-6zy4kwwRZ4O3T6qN7QLQmvx3ztrnm",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 1,
#      "prompt_tokens": 831,
#      "total_tokens": 832
#    }
#  },
#  <OpenAIObject text_completion id=cmpl-6zy4lbOHnuVMs4GSOLEyWktgwB78F at 0x7fc6703f3810> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": " true"
#      }
#    ],
#    "created": 1680226959,
#    "id": "cmpl-6zy4lbOHnuVMs4GSOLEyWktgwB78F",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 1,
#      "prompt_tokens": 683,
#      "total_tokens": 684
#    }
#  },
#  <OpenAIObject text_completion id=cmpl-6zy4lCzdZ4fIfIjOCU6AOHJp3PlTL at 0x7fc6704d75e0> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": " true"
#      }
#    ],
#    "created": 1680226959,
#    "id": "cmpl-6zy4lCzdZ4fIfIjOCU6AOHJp3PlTL",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 1,
#      "prompt_tokens": 838,
#      "total_tokens": 839
#    }
#  },
#  <OpenAIObject text_completion id=cmpl-6zy4lU0gT6xZEdkjkm14JIkoDbiLS at 0x7fc670400310> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": " false"
#      }
#    ],
#    "created": 1680226959,
#    "id": "cmpl-6zy4lU0gT6xZEdkjkm14JIkoDbiLS",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 1,
#      "prompt_tokens": 671,
#      "total_tokens": 672
#    }
#  },
#  <OpenAIObject text_completion id=cmpl-6zy4mtGR1kW2FQrM3w2oGOzyis6OY at 0x7fc6704ceef0> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": " false"
#      }
#    ],
#    "created": 1680226960,
#    "id": "cmpl-6zy4mtGR1kW2FQrM3w2oGOzyis6OY",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 1,
#      "prompt_tokens": 762,
#      "total_tokens": 763
#    }
#  },
#  <OpenAIObject text_completion id=cmpl-6zy4mUIxhacHevUEIcVkEsj33x1od at 0x7fc6704008b0> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": " false"
#      }
#    ],
#    "created": 1680226960,
#    "id": "cmpl-6zy4mUIxhacHevUEIcVkEsj33x1od",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 1,
#      "prompt_tokens": 681,
#      "total_tokens": 682
#    }
#  },
#  <OpenAIObject text_completion id=cmpl-6zy4mgteV3UgULbKCBqs2oIf4WJpj at 0x7fc670400ea0> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": " false"
#      }
#    ],
#    "created": 1680226960,
#    "id": "cmpl-6zy4mgteV3UgULbKCBqs2oIf4WJpj",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 1,
#      "prompt_tokens": 760,
#      "total_tokens": 761
#    }
#  },
#  <OpenAIObject text_completion id=cmpl-6zy4nv6JzqJsMrDbnRWh361Pp0DlV at 0x7fc6704ceb80> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": " true"
#      }
#    ],
#    "created": 1680226961,
#    "id": "cmpl-6zy4nv6JzqJsMrDbnRWh361Pp0DlV",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 1,
#      "prompt_tokens": 781,
#      "total_tokens": 782
#    }
#  },
#  <OpenAIObject text_completion id=cmpl-6zy4njGdWwzVYwbU2LlcraKwWwlbu at 0x7fc670400540> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": " false"
#      }
#    ],
#    "created": 1680226961,
#    "id": "cmpl-6zy4njGdWwzVYwbU2LlcraKwWwlbu",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 1,
#      "prompt_tokens": 722,
#      "total_tokens": 723
#    }
#  },
#  <OpenAIObject text_completion id=cmpl-6zy4oA7l1tF5e56Mo5OuQypH8xxGN at 0x7fc6703cbb80> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": " true"
#      }
#    ],
#    "created": 1680226962,
#    "id": "cmpl-6zy4oA7l1tF5e56Mo5OuQypH8xxGN",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 1,
#      "prompt_tokens": 774,
#      "total_tokens": 775
#    }
#  },
#  <OpenAIObject text_completion id=cmpl-6zy4oCC220DpooyT6ajWtaHCq5KVU at 0x7fc6703cb7c0> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": " true"
#      }
#    ],
#    "created": 1680226962,
#    "id": "cmpl-6zy4oCC220DpooyT6ajWtaHCq5KVU",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 1,
#      "prompt_tokens": 772,
#      "total_tokens": 773
#    }
#  },
#  <OpenAIObject text_completion id=cmpl-6zy4omHsHFGHNtDoCIrZW5RD4redt at 0x7fc6703cb720> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": " true"
#      }
#    ],
#    "created": 1680226962,
#    "id": "cmpl-6zy4omHsHFGHNtDoCIrZW5RD4redt",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 1,
#      "prompt_tokens": 715,
#      "total_tokens": 716
#    }
#  },
#  <OpenAIObject text_completion id=cmpl-6zy4pnRx700FHdjAZG0chrIriixIm at 0x7fc6703cbea0> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": "\nunknown"
#      }
#    ],
#    "created": 1680226963,
#    "id": "cmpl-6zy4pnRx700FHdjAZG0chrIriixIm",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 2,
#      "prompt_tokens": 720,
#      "total_tokens": 722
#    }
#  },
#  <OpenAIObject text_completion id=cmpl-6zy4p7hL0b7DQSQMMHtt6HTdUQK6u at 0x7fc6703e5d10> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": " false"
#      }
#    ],
#    "created": 1680226963,
#    "id": "cmpl-6zy4p7hL0b7DQSQMMHtt6HTdUQK6u",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 1,
#      "prompt_tokens": 702,
#      "total_tokens": 703
#    }
#  },
#  <OpenAIObject text_completion id=cmpl-6zy4pofIpP14QHUAjDUgVJmyeAAao at 0x7fc6703e5400> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": " true"
#      }
#    ],
#    "created": 1680226963,
#    "id": "cmpl-6zy4pofIpP14QHUAjDUgVJmyeAAao",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 1,
#      "prompt_tokens": 765,
#      "total_tokens": 766
#    }
#  },
#  <OpenAIObject text_completion id=cmpl-6zy4qniT6b9xekQM7MunpGrK1mPdd at 0x7fc6703f0b30> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": " true"
#      }
#    ],
#    "created": 1680226964,
#    "id": "cmpl-6zy4qniT6b9xekQM7MunpGrK1mPdd",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 1,
#      "prompt_tokens": 714,
#      "total_tokens": 715
#    }
#  },
#  <OpenAIObject text_completion id=cmpl-6zy4q5iJzQdoyXQqNxfT3qLZ2bFSn at 0x7fc6704cec70> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": " true"
#      }
#    ],
#    "created": 1680226964,
#    "id": "cmpl-6zy4q5iJzQdoyXQqNxfT3qLZ2bFSn",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 1,
#      "prompt_tokens": 767,
#      "total_tokens": 768
#    }
#  },
#  <OpenAIObject text_completion id=cmpl-6zy4qqQXmtr1pGJ2n6BISAnMY0HxA at 0x7fc6703f0ef0> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": " true"
#      }
#    ],
#    "created": 1680226964,
#    "id": "cmpl-6zy4qqQXmtr1pGJ2n6BISAnMY0HxA",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 1,
#      "prompt_tokens": 763,
#      "total_tokens": 764
#    }
#  },
#  <OpenAIObject text_completion id=cmpl-6zy4q1i4dRVjbHj04paasxmNVqBqD at 0x7fc6703cbcc0> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": " true"
#      }
#    ],
#    "created": 1680226964,
#    "id": "cmpl-6zy4q1i4dRVjbHj04paasxmNVqBqD",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 1,
#      "prompt_tokens": 755,
#      "total_tokens": 756
#    }
#  },
#  <OpenAIObject text_completion id=cmpl-6zy4riL5jA5TrmhcrVFYdXUBIX0T4 at 0x7fc6703f03b0> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": " true"
#      }
#    ],
#    "created": 1680226965,
#    "id": "cmpl-6zy4riL5jA5TrmhcrVFYdXUBIX0T4",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 1,
#      "prompt_tokens": 915,
#      "total_tokens": 916
#    }
#  },
#  <OpenAIObject text_completion id=cmpl-6zy4rNXind7aeid1Fk3n6jqIpKAPT at 0x7fc6703582c0> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": " false"
#      }
#    ],
#    "created": 1680226965,
#    "id": "cmpl-6zy4rNXind7aeid1Fk3n6jqIpKAPT",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 1,
#      "prompt_tokens": 677,
#      "total_tokens": 678
#    }
#  },
#  <OpenAIObject text_completion id=cmpl-6zy4rYGPXV2ysFXg8rWuEQszrvFz4 at 0x7fc6703bfc70> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": " true"
#      }
#    ],
#    "created": 1680226965,
#    "id": "cmpl-6zy4rYGPXV2ysFXg8rWuEQszrvFz4",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 1,
#      "prompt_tokens": 675,
#      "total_tokens": 676
#    }
#  },
#  <OpenAIObject text_completion id=cmpl-6zy4rHnljaXApt8noiePOip0DyTju at 0x7fc6704cf6d0> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": " false"
#      }
#    ],
#    "created": 1680226965,
#    "id": "cmpl-6zy4rHnljaXApt8noiePOip0DyTju",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 1,
#      "prompt_tokens": 667,
#      "total_tokens": 668
#    }
#  },
#  <OpenAIObject text_completion id=cmpl-6zy4sbghNJ81h35wjHOcKkCjWePzp at 0x7fc6703bf720> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": " false"
#      }
#    ],
#    "created": 1680226966,
#    "id": "cmpl-6zy4sbghNJ81h35wjHOcKkCjWePzp",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 1,
#      "prompt_tokens": 696,
#      "total_tokens": 697
#    }
#  },
#  <OpenAIObject text_completion id=cmpl-6zy4sxCdMLDtGlcs0yzzVHnV8599S at 0x7fc6703b1d10> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": " true"
#      }
#    ],
#    "created": 1680226966,
#    "id": "cmpl-6zy4sxCdMLDtGlcs0yzzVHnV8599S",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 1,
#      "prompt_tokens": 765,
#      "total_tokens": 766
#    }
#  },
#  <OpenAIObject text_completion id=cmpl-6zy4sCoTYQby6syVEqhtEezUrfvTB at 0x7fc6703b1cc0> JSON: {
#    "choices": [
#      {
#        "finish_reason": "stop",
#        "index": 0,
#        "logprobs": null,
#        "text": " true"
#      }
#    ],
#    "created": 1680226966,
#    "id": "cmpl-6zy4sCoTYQby6syVEqhtEezUrfvTB",
#    "model": "text-davinci-003",
#    "object": "text_completion",
#    "usage": {
#      "completion_tokens": 1,
#      "prompt_tokens": 744,
#      "total_tokens": 745
#    }
#  }]

# %%
pred = [output[i]['choices'][0]['text'] in (' true') for i in range(30)]

# %%
validation = np.array(answer[30:60]) == np.array(pred)
validation.sum() / len(validation)
# Out:
# 0.9666666666666667
